# %% [markdown]
# <a href="https://colab.research.google.com/github/PritikaB/AdaBoost-and-Gradient-Boost-for-Predictive-Analytics/blob/master/NLP_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NLP Pipeline**
#
# ![image.png](data:image/png;base64,...)

# %%
pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
pip install linguistics
# Out:
# Collecting linguistics
#   Downloading linguistics-2022.5.8-py3-none-any.whl (34 kB)
# Collecting abstract (from linguistics)
#   Downloading abstract-2022.7.10-py3-none-any.whl (27 kB)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (from linguistics) (3.7.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from linguistics) (2.31.0)
# Collecting jellyfish (from linguistics)
#   Downloading jellyfish-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: editdistance in /usr/local/lib/python3.10/dist-packages (from linguistics) (0.6.2)
# Collecting chronometry (from linguistics)
#   Downloading chronometry-2020.11.12-py3-none-any.whl (29 kB)
# Collecting slytherin (from linguistics)
#   Downloading slytherin-2020.11.12-py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from linguistics) (1.25.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from linguistics) (1.5.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from linguistics) (2.1.0+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from linguistics) (4.37.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from abstract->linguistics) (0.20.1)
# Collecting base32hex (from abstract->linguistics)
#   Downloading base32hex-1.0.2.tar.gz (2.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting colouration (from abstract->linguistics)
#   Downloading colouration-2020.7.26-py3-none-any.whl (20 kB)
# Collecting sklearn (from chronometry->linguistics)
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# **Text Cleaning**

# %% [markdown]
# Unicode normalization

# %%
text = 'I am faculty at PIEMR $$$$ 🤣'
print(text)
text2 = text.encode('utf-8')
print(text2)
# Out:
# I am faculty at PIEMR $$$$ 🤣
# b'I am faculty at PIEMR $$$$ \xf0\x9f\xa4\xa3'

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.corpus import stopwords
from string import punctuation

eng_stopwords = stopwords.words('english')

text = "Mr. John O'Neil works at Wonderland, located at 245 Goleta Avenue, CA., 74208."

words = word_tokenize(text)

print(words)

# remove stopwords, punctuations, digits
for w in words:
    if w not in eng_stopwords and w not in punctuation and not w.isdigit():
        print(w)
# Out:
# ['Mr.', 'John', "O'Neil", 'works', 'at', 'Wonderland', ',', 'located', 'at', '245', 'Goleta', 'Avenue', ',', 'CA.', ',', '74208', '.']
# Mr.
# John
# O'Neil
# works
# Wonderland
# located
# Goleta
# Avenue
# CA.

# %% [markdown]
# Stemming and lemmatization

# %%
## Stemming
from nltk.stem.porter import PorterStemmer
stemmer = PorterStemmer()

words = ['cars','revolution', 'better']
print([stemmer.stem(w) for w in words])
# Out:
# ['car', 'revolut', 'better']

# %%
nltk.download('wordnet')
## Lemmatization
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

## Wordnet requires POS of words
poss = ['n','n','a']

for w,p in zip(words,poss):
    print(lemmatizer.lemmatize(w, pos=p))
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Mr.
# John
# O'Neil
